# %%
from tensorflow import keras
from tensorflow.keras import layers

import numpy as np
import random
import io

# %%
path = keras.utils.get_file(
    "nietzsche.txt", origin="https://s3.amazonaws.com/text-datasets/nietzsche.txt"
)
with io.open(path, encoding="utf-8") as f:
    text = f.read().lower()
text = text.replace("\n", " ")  # We remove newlines chars for nicer display
print("Corpus length:", len(text))

chars = sorted(list(set(text)))
print("Total chars:", len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i : i + maxlen])
    next_chars.append(text[i + maxlen])
print("Number of sequences:", len(sentences))

x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 0s 0us/step
# Corpus length: 600893
# Total chars: 56
# Number of sequences: 200285

# %%
model = keras.Sequential(
    [
        keras.Input(shape=(maxlen, len(chars))),
        layers.LSTM(128),
        layers.Dense(len(chars), activation="softmax"),
    ]
)
optimizer = keras.optimizers.RMSprop(learning_rate=0.01)
model.compile(loss="categorical_crossentropy", optimizer=optimizer)

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype("float64")
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
epochs = 10
batch_size = 128

for epoch in range(epochs):
    model.fit(x, y, batch_size=batch_size, epochs=1)
    print()
    print("Generating text after epoch: %d" % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print("...Diversity:", diversity)

        generated = ""
        sentence = text[start_index : start_index + maxlen]
        print('...Generating with seed: "' + sentence + '"')

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.0
            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]
            sentence = sentence[1:] + next_char
            generated += next_char

        print("...Generated: ", generated)
        print()
# Out:
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.9122
#
# Generating text after epoch: 0
# ...Diversity: 0.2
# ...Generating with seed: "pirit, will still not be fully permeated"
# ...Generated:   the spirit and the soul of the soul of the soul of the sout the supprited the metain the soul and and and and in the sout the sout the sout the soul of the sout and the sout the sour in the sout the sout the sout and the sout the sense that is all the sout of the sense the sout the soul of the sout the so the sense the secress of the sech and and and and in the sout of the southing the sout the s
#
# ...Diversity: 0.5
# ...Generating with seed: "pirit, will still not be fully permeated"
# ...Generated:   that is all the sout the sense the former as it has sore the will one pressing not is an all the southing the incertanting of the great to the countent the the something imperfor of the emptiation it power the south of a consequently the sout considere all the importing that it was man more the and the retracted the secress and as order doase of the histeritation of the will not the reasons that
#
# ...Diversity: 1.0
# ...Generating with seed: "pirit, will still not be fully permeated"
# ...Generated:   sactuat leash of order ours3ly , vaide with the considulect, as lifoman dent, pawner which understsantity morans? dase is one's alcostifuscule decest tamen to jost that one wleever an prespision ow. the "them the firrobstinctable fremphary be upeonss?'n. the prices as resust becorait. tise considiatcufuren to the froms--nath as it cakent stal obded as he comnanterant of the splessy." ours fered i
#
# ...Diversity: 1.2
# ...Generating with seed: "pirit, will still not be fully permeated"
# ...Generated:  , -thus life the an an moduffer could i us is in poss.."t. the wibt of reatry?" in the righteits-mishe the self: beard moves appepohiture and phrissent things: the fill ssment orivivation or -dobary." ); dova them leas cleefest to the so arcrity sitelue in ? ciemb, adpare marifors woll puw natises, art at hame to athen everm: befort least,s, theserf pviress, truch a hightwiswant?  i. it word yet,
#
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.5643
#
# Generating text after epoch: 1
# ...Diversity: 0.2
# ...Generating with seed: "dy and calm as we are now, and thereby p"
# ...Generated:  reseration of the subjection of the soul of the soul of the soul of the soul of the most and the there as the something of the same as the artifices and sensible of the comparines of the comparine of the same and a subjection of the sense and the most as the sees the subjection of the something the common it is a soulse and the pottering of the something of the same and as the sees the condition o
#
# ...Diversity: 0.5
# ...Generating with seed: "dy and calm as we are now, and thereby p"
# ...Generated:  aintest to paysion and subjection of their experiencess and been the expecies now the any here has an art and the mean same himself self and its philosophers and some stribt by more in the former there are in the about in the stragge itself former the restructes and conscience of the masterality of the instinct itself to perhaps a last that abost which all the not as a come of the sendume and dece
#
# ...Diversity: 1.0
# ...Generating with seed: "dy and calm as we are now, and thereby p"
# ...Generated:  erhaps vaielvese, be mait of the oderawed upon moreaver, hence as long in the out.n: love ineny, the corcupility of such a work in a particlized. every ditf thems fear you estial out as the sorlestic hee? and personal his nater; the dustion what ba new. their whole ancire for hshow a trackeatot coumtable vality the a-tough passibual to may instlatod found murtor also in upmun. of kelpoed to hope t
#
# ...Diversity: 1.2
# ...Generating with seed: "dy and calm as we are now, and thereby p"
# ...Generated:  ayliaty.kapimicoly nod reskention his natery", co,credy this own shill there: who disceptious. the thind nameres. wettined." at obhame if a impolory in snishedwed if deer po the human artioar rosirdom every could he reyquation obscuritale, but only to cate of those 2erronake itself whility will nece be decting in    yow mexeatially. that in es, ideality, of nimiaticaltistacior; of colimed must   v
#
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.4761
#
# Generating text after epoch: 2
# ...Diversity: 0.2
# ...Generating with seed: "ranted that even in this condition of so"
# ...Generated:  mething of the something of the conscionstic of the sense of the same and and in the same man and hall and in the same and self-read to the stands that it is a soul to the conscionsticle and for the same man and the sense of the same and praces and something of the same and for the same man and prefection of the sense of the soul of the same and for the something of the same the man in the possibl
#
# ...Diversity: 0.5
# ...Generating with seed: "ranted that even in this condition of so"
# ...Generated:  mething in everything of sublimanter and a conscionstifual and a depreseeds of interest and error of the counthing the still the case of the passion of leadness which have and the concerning the sound and in the subresses the something in the way and things in a means of the truth. the false which the soul to the exception of the powise and something of the heady seems in the still men thought suf
#
# ...Diversity: 1.0
# ...Generating with seed: "ranted that even in this condition of so"
# ...Generated:  , the happy to one too despected, the sormented full mode, time is sacrifical will for the infred has feelings into blook of peshim torin dedicatous intemplet plaken hermarterake oming of man pleasure who day--whatever man exception, our old vanienge of cazaby will nalure of cosefulliring him ashe, has it is deficultzed about proterons. unscience and owness obgeous alless othergher in whomver comm
#
# ...Diversity: 1.2
# ...Generating with seed: "ranted that even in this condition of so"
# ...Generated:  terble tranking rars even therebouss. he greake raze man:  kposuight to kind of failous."ingle in, appraguicity and which i knowleds that or to does rosatry when in clve? type and the cultactous to yratestop. invemt, "humbling the too trayph is new exolun intelprecde idamely! self-rely indegerming sathsmenc; but agays its-lexcetir, of this una, notamal cl mow--so tajnes, it is the notions. le: at
#
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.4332
#
# Generating text after epoch: 3
# ...Diversity: 0.2
# ...Generating with seed: "nker, in every "causal-connection" and ""
# ...Generated:  man and an an according the preserves to the soul of the soul of the consciously and such a strength, and the preserves and subliman and preserves the strive the preserves and and subtles of the same the consciously and subliman and and preserves and and soul of the assersion of the senses of the present to the self and consciously and subliman and preserves and subliman and speak the moder to the
#
# ...Diversity: 0.5
# ...Generating with seed: "nker, in every "causal-connection" and ""
# ...Generated:  the interpreness to the interpreces be the morality of the soul of the subjected to allow one as a personal problem and provery the real in its contempturation of comparises to the moduct seem the could the present to the prepart the prosons in the present. it was the consequently such a person of the modernable for the most in the cause of such our something of action of the same self and conscio
#
# ...Diversity: 1.0
# ...Generating with seed: "nker, in every "causal-connection" and ""
# ...Generated:  had contrisreredry there"io, by evil of the mutually not living his "old the world to know conception of parre--with knoding reided to power what may be irdeid civils" or simsance rigidadity,      the  and itself for the but as consciously part of unvoints to personality of the "such moreth midsman bo ban if the free time. it is the end char sa-fibat to brought great this treatism for its and kpea
#
# ...Diversity: 1.2
# ...Generating with seed: "nker, in every "causal-connection" and ""
# ...Generated:  sthil, for slying of indeed--on suve i over als ten enult, and reverated may be fore; in a philosopher its personalish amol that hat to divincy--. 1fanises soon for is, a chissed, nothing of the fryed forcy, and, even have enasis apeald parte to fathy witt woman beauch fan of they .  is natureid moder which; per. what god ouble, learn in gives upan remained and turely something a molicitay made."
#
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.4036
#
# Generating text after epoch: 4
# ...Diversity: 0.2
# ...Generating with seed: " world an incalculable strength of intel"
# ...Generated:  lectual take the an an end an experiental the moral concerning to the more the true to the concerning the form of the truth of the consciousness, the sense of the consciousness, and the consciousness of the concerning the concerning the concerning to the despect of the more moral concerning to the concerning to the will to the same the secret and concerning the moral to the concerning to the conce
#
# ...Diversity: 0.5
# ...Generating with seed: " world an incalculable strength of intel"
# ...Generated:  lectual thought to the things and remolved, an experiences and for concerning to the morality and not the forms and still in the being of the confuse to contrary and the contrary, as a strong at any concerning profound the consciousness, everything to respect of the explanation and evil at when the things and assort of the works the same the sublime the interpreter, and as a feneration and power t
#
# ...Diversity: 1.0
# ...Generating with seed: " world an incalculable strength of intel"
# ...Generated:  lectue andarenticlion, the truth, with thepe all thinking with it is, time, however, the feling hum we meelion of sense on justhis paninw of state of the super-atinis--theuresful with they, it is not do the despipe thus who can he suppose of experient), in labs and comples many with its oft right of the victory and it, not indespain to more volume, was not wite them axterned to its distortenes, it
#
# ...Diversity: 1.2
# ...Generating with seed: " world an incalculable strength of intel"
# ...Generated:  light than that iove priged itself belongs for itselivation--in himself; the anceratant--they, "mever. this oliwity. does this learned actsy, which faie means of hidde, a cruls authleas ". begning, enalable philosophy for kinl dden interrewates,"; that they things, which user" inverital indwarnd tend does judt of chumc""..--rilith, itself, and the straighterness; and will say, must be that becomen
#
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3832
#
# Generating text after epoch: 5
# ...Diversity: 0.2
# ...Generating with seed: "cent men (and as such, with the most del"
# ...Generated:  ight in the present and an and the religious and who have the present to the motive of the fact the present to an and and who man in the super-in the process and and the higher to contemplation of the super--and the present and souls and and and strange the super-of the fact that is the present to the sense of the present and thereby and man is not be an and in the present and souls and and the pr
#
# ...Diversity: 0.5
# ...Generating with seed: "cent men (and as such, with the most del"
# ...Generated:  ignts and living and the poses in that the man and for what all that in the resting does not be above all the sughts and some and former remoted to the connective distinction of the mind thereby who know the scientific europe, for the most which the present and sughts of his above there is all that there is a disdeal destinution of discelled and even the hand. the man is the great the most procisi
#
# ...Diversity: 1.0
# ...Generating with seed: "cent men (and as such, with the most del"
# ...Generated:  ightes rigotoesed it with instear to goodness:---ow man deef, aker and limit, then epsen and, strengeh that rude; but with the "  viyously lears to stwor---mind hiples man always regarablems sinking, but he reverse almost which an englais oneself, a finar people, we ethic superfly which intoribe that thus. that where has (approsth.owheraby.  juus nouremy of planouscits philosopher, a invertion for
#
# ...Diversity: 1.2
# ...Generating with seed: "cent men (and as such, with the most del"
# ...Generated:  iving of numbery," of suppising, the shige so ecoe2's for sentie's the lid bome to thiourly imhergerdfulgy, littdely, of . in mey mninagok--oo, it is "feom only jowe love musive lahast of what untese-. woman ussial.h,--and anothering-. lears ad"-ring-s ame-bary, effect of human anyic huib: chin-glostayh and meaned emotter-gain. where own meeft fath xighd, a laughten ? yo nour-alor-san, soul--certu
#
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3670
#
# Generating text after epoch: 6
# ...Diversity: 0.2
# ...Generating with seed: "ond of union. morality results from comp"
# ...Generated:  rehensible and supportental to the sense of the subject of the subject of the subject of the subject of the subjection of the subject of the more the moral philosophy of the individuals and individuals and and the subject of the subject of the subject of the subject of the subjection of the subject of the sense of the sense of the subject of the subject of the moral as the more the conscience the
#
# ...Diversity: 0.5
# ...Generating with seed: "ond of union. morality results from comp"
# ...Generated:  rehense self of its added the self of our notion of the something at morality of the person is the standard of the at their powerful--and instinct is perhaps not also and strength of and hiddence in the lightnal is a severitter in the prides and subject of them, and there are the self-satisfaction of germany, and the "good and and the really man in itself. the world therefore, it is nature of the
#
# ...Diversity: 1.0
# ...Generating with seed: "ond of union. morality results from comp"
# ...Generated:  redeated). and only the good moning and does notents with the felist that everywain way schoolar very all marhied for so the word asserte men which much it? when the reforie at aken the purtable su"ferioustful sloover as i moloon and brusely conunce, it ided oraw, hard powersly open) aftres part, of love is a severre, reals morality out of an end ideage, into harsem"ms to an indimials, habituality
#
# ...Diversity: 1.2
# ...Generating with seed: "ond of union. morality results from comp"
# ...Generated:  rehension the used and en"god with seasest or dwell cassur-sist as i all whatevers, of pry less mankindk who ko somebid to 'eche mortiation of are this wite--calls" breach called ba )trainary insists of our none man atrans with which have nocdingry or, the part of an sought," in shooless, sombard. neading, and their cymely and every contruceness wurldomeful, and gable skeqtentness, evi, tarhnding:
#
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3528
#
# Generating text after epoch: 7
# ...Diversity: 0.2
# ...Generating with seed: "each surrenders to the other what the ot"
# ...Generated:  her the soul of the subject of the soul of the soul of the soul of the soul of the soul of the soul of the constrained to the soul of the soul of the strength of the subject to the such as the soul of the soul of the soul of the thing the soul of the strength of the subject of the subject of the soul of the soul of the soul of the power of the soul of the something which is the power of the soul o
#
# ...Diversity: 0.5
# ...Generating with seed: "each surrenders to the other what the ot"
# ...Generated:  her the subtless to does to the assimilage of the conditions of the subtless of love of the states with it is no sufferer the father and specially, hard free the domain of the same despress man who have ambention when the sense--the free the advance of the states of it. the insistan of the constrain such a subtlety the soul of the states in the most something the fact time a whole their subliming
#
# ...Diversity: 1.0
# ...Generating with seed: "each surrenders to the other what the ot"
# ...Generated:  hers to exultite matkedations, we valle has a weakere, the refined, siredive  that whyn hence and whom--it this what man reverence of souls, dream poing truthjuce exgively to it. the learning, a other if what the soul. the happiness, as the clearns, no man and capade and wosh and the most sisuated and pate  leves in densite this eternal franse it is modes of a stis, humious-mixterine. the viled as
#
# ...Diversity: 1.2
# ...Generating with seed: "each surrenders to the other what the ot"
# ...Generated:  her nature, and jussifying, vanity hence in the dlesmerd science: but not to ourstealigatmenness, on a remorranife. hence sontly of the most prisenve) to be supretible,, but necessarily belitten community," how certaint to the feitley with creed, in i have do as you more booud invatually evil. that treed have early dypmenciminatity, with as new marsined by chase, not =theory of freatder maining ti
#
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3414
#
# Generating text after epoch: 8
# ...Diversity: 0.2
# ...Generating with seed: "eaps and obviates all dangers in word an"
# ...Generated:  d what is a problem of the sublimation of the strange the strength of the strength of the most subtle to the strength of the standard of the process of the sublimation of the most processes and strong and for the most strange the strong of the subjection of the something in the most sacrificed to the most something in the strength of the individual in the strength of the morality and the most stre
#
# ...Diversity: 0.5
# ...Generating with seed: "eaps and obviates all dangers in word an"
# ...Generated:  d the end of the truth sublimation and intercele believe it is all sight of the subjection of every himself gord and strong of the its and an above the the position of comprehension of the morality.
#
# ...Diversity: 1.0
# ...Generating with seed: "eaps and obviates all dangers in word an"
# ...Generated:  d 'some, to plato when vo his to cosility of sights and reconceoner, but proplemining this portulicity, but philosophers that is a retard state from the subjection of repeep or possibility the master the "training bewaration insigh problemm "nation to every now the supersiviag, than in corre.  x3. the relienes some.u the nrution and lated at the strected again creitr; and or new is! which so must
#
# ...Diversity: 1.2
# ...Generating with seed: "eaps and obviates all dangers in word an"
# ...Generated:  d luthest liudogy first ecces., hear blegated them altest known's self-occasions of howe, require under without of the mude ragable vanity with suppes of distrepsived hever f credities and intemption" as imaginate really and state nature, one's rike myans riifflut els: undan, in-plant-an, for other this he bemonationts; wnome is fooly.. does make that the not, for seetis right, as "inarncortencein
#
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3331
#
# Generating text after epoch: 9
# ...Diversity: 0.2
# ...Generating with seed: "ed for faith's sake.=--no power can sust"
# ...Generated:  imently and also the standard that is a standard the soul of the soul of the soul of the same as the soul of the soul and a standard for the sense of the possesses the most soul of the soul of the soul of the individual of the same man and the world of the possesses and the sense of the most soul of the soul and presence of the soul of the soul of the most soul of the soul of the soul of the soul
#
# ...Diversity: 0.5
# ...Generating with seed: "ed for faith's sake.=--no power can sust"
# ...Generated:  ifices of the will and the hands the perceptions, and consequence of the truth in the consequence of the present stands an as a possesse of an extent of the soul the state of the same minal contemporarily and givest all wors. in the "world: the long and destitud as a firmly a from so desire herself, to be hearts without an interprete.   thokest self-and the individual how always for the light of t
#
# ...Diversity: 1.0
# ...Generating with seed: "ed for faith's sake.=--no power can sust"
# ...Generated:  ase express"--as the gint this consciand who is to pain as will meactering and peclegation with re-can we feel far conpertent, far as conduct," in been they are fener, does for them is elevation of since of resilkent son who, remained wele ownonk of distrability, to as the most does no spectally commonisms more infunce for the mimloesing ise-"now but so care humanity all that that others! everythi
#
# ...Diversity: 1.2
# ...Generating with seed: "ed for faith's sake.=--no power can sust"
# ...Generated:  an opingry of antightness and from which coremerocraty  womany of decacre illdiecting; possesses too. and his drypiple does not new skence, can asher o a?creasuratisus all bvasion. that oksy into everything that glan to mage thay it had recocrie; .  2 an the soul fashur new man marwiveed for an ingentimular, long on called in oppinisible; have presiud, with hear that he is not--that order herdmeto
